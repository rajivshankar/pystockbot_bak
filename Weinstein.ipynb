# %% [markdown]
# # Technical Analysis
# This is a test on replicating the stage analysis explained in Stan Weinstein's book

# %% [markdown]
# ## Import all the required Modules

# %%
# import the key modules
import datetime as dt
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

from stockbot import preprocessing as prep
from stockbot import data_collection as dc
# Out:
# C:\Users\Rajiv\.conda\envs\stockbot\lib\site-packages\pandas_datareader\compat\__init__.py:7: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   from pandas.util.testing import assert_frame_equal

# %%
# Make the style on matplot lib
from matplotlib import style
style.use('ggplot')
# %matplotlib inline

# %% [markdown]
# ### Set logger for the routines

# %%
"""
In jupyter notebook simple logging to console and file:
"""
import logging
import sys

logging.basicConfig(
    level=logging.INFO, 
    format='[{%(filename)s:%(lineno)d} %(levelname)s - %(message)s',
    handlers=[
#         logging.FileHandler(filename='tmp5a.log'),
        logging.StreamHandler(sys.stdout)
    ]
)

# Test
logger = logging.getLogger('LOGGER_NAME')
logger.debug('This message should go to the log file and to the console')
logger.info('So should this')
logger.warning('And this, too')
# Out:
# [{<ipython-input-3-6bc8b2743ab3>:19} INFO - So should this
# [{<ipython-input-3-6bc8b2743ab3>:20} WARNING - And this, too

# %%
def logged(func):
    def wrapper(*args, **kwargs):
        print('Calling', func.__name__)
        return func(*args, **kwargs)
    return wrapper

# %% [markdown]
# ## The process to pick stocks
# - Get a ticker from the list of tickers
# - get the prices for the last 5 years for the ticker
# - Calculate the Weighted Moving Average for the stock
# - Calculate the slope of MA at every stage
# - Collate the volumes
# - Calculate support
# - Calculate the number of times and the time for which this support has been tested
# - Calculate Resistance
# - Calculate the number of times and the time for this this resistance held
# - Calculate the Trading Range for the stock
# - Calculate the market performance and the relative strength
# - Spot Continuation points for traders

# %%
# Set the ticker and the index ticker
ticker = "XOM"
index_ticker = '^GSPC'

# %%
df = prep.prepare_analytical_data(ticker, index_ticker)
# Out:
# [{data_collection.py:45} INFO - end_date: 2020-08-02 00:00:00 and max_index: 2020-07-31 00:00:00
# [{data_collection.py:46} INFO - start_date: 2015-08-04 00:00:00 and min_index: 2015-08-04 00:00:00
# [{data_collection.py:49} WARNING - Returning an empty dataframe
# [{data_collection.py:95} INFO - Dumping data for XOM
# [{data_collection.py:45} INFO - end_date: 2020-08-02 00:00:00 and max_index: 2020-07-31 00:00:00
# [{data_collection.py:46} INFO - start_date: 2015-08-04 00:00:00 and min_index: 2015-08-04 00:00:00
# [{data_collection.py:49} WARNING - Returning an empty dataframe
# [{data_collection.py:95} INFO - Dumping data for ^GSPC

# %%
print(df.head())
# Out:
#             XOM Adj Close    SMA 10W  Trend SMA 10W  Stage Trend 10W  \
# Date
# 2015-08-04      62.495750  62.495750         0.0000              NaN
# 2015-08-05      62.495750  62.495750         0.0000              NaN
# 2015-08-06      63.240810  62.744104         0.0040              1.0
# 2015-08-07      62.220409  62.613180        -0.0021             -1.0
# 2015-08-10      63.775311  62.845606         0.0037              1.0
#
#               SMA 30W  Trend SMA 30W  Stage Trend 30W  XOM Volume  \
# Date
# 2015-08-04  62.495750         0.0000              NaN  18874400.0
# 2015-08-05  62.495750         0.0000              NaN  16544400.0
# 2015-08-06  62.744104         0.0040              1.0  13005200.0
# 2015-08-07  62.613180        -0.0021             -1.0  12187600.0
# 2015-08-10  62.845606         0.0037              1.0  14876000.0
#
#             Volume SMA 30D  ^GSPC Adj Close  ...       RSM  Price History 1W  \
# Date                                         ...
# 2015-08-04    1.887440e+07      2093.320068  ...  0.000000              True
# 2015-08-05    1.770940e+07      2099.840088  ... -0.155492              True
# 2015-08-06    1.614133e+07      2083.560059  ...  1.208832              True
# 2015-08-07    1.515290e+07      2077.570068  ... -0.102857             False
# 2015-08-10    1.509752e+07      2104.179932  ...  0.877036              True
#
#             Price History 2W  Price History 3W  Price History 001M  \
# Date
# 2015-08-04              True              True                True
# 2015-08-05              True              True                True
# 2015-08-06              True              True                True
# 2015-08-07             False             False               False
# 2015-08-10              True              True                True
#
#             Price History 003M  Price History 006M  Price History 012M  \
# Date
# 2015-08-04                True                True                True
# 2015-08-05                True                True                True
# 2015-08-06                True                True                True
# 2015-08-07               False               False               False
# 2015-08-10                True                True                True
#
#             Price History 036M  Price History 060M
# Date
# 2015-08-04                True                True
# 2015-08-05                True                True
# 2015-08-06                True                True
# 2015-08-07               False               False
# 2015-08-10                True                True
#
# [5 rows x 21 columns]

# %%
df['Trend SMA 10W'] = df['Trend SMA 10W'].fillna(0)
print(df['Trend SMA 10W'].head())
# Out:
# Date
# 2015-08-04    0.0000
# 2015-08-05    0.0000
# 2015-08-06    0.0040
# 2015-08-07   -0.0021
# 2015-08-10    0.0037
# Name: Trend SMA 10W, dtype: float64

# %%
last_analysis_days=365
df_filtered = df[df.index >= df.index.max() - dt.timedelta(last_analysis_days)]

# %%
df_filtered = df

# %%
print(df_filtered.head())
# Out:
#             XOM Adj Close    SMA 10W  Trend SMA 10W  Stage Trend 10W  \
# Date
# 2015-08-04      62.495750  62.495750         0.0000              NaN
# 2015-08-05      62.495750  62.495750         0.0000              NaN
# 2015-08-06      63.240810  62.744104         0.0040              1.0
# 2015-08-07      62.220409  62.613180        -0.0021             -1.0
# 2015-08-10      63.775311  62.845606         0.0037              1.0
#
#               SMA 30W  Trend SMA 30W  Stage Trend 30W  XOM Volume  \
# Date
# 2015-08-04  62.495750         0.0000              NaN  18874400.0
# 2015-08-05  62.495750         0.0000              NaN  16544400.0
# 2015-08-06  62.744104         0.0040              1.0  13005200.0
# 2015-08-07  62.613180        -0.0021             -1.0  12187600.0
# 2015-08-10  62.845606         0.0037              1.0  14876000.0
#
#             Volume SMA 30D  ^GSPC Adj Close  ...       RSM  Price History 1W  \
# Date                                         ...
# 2015-08-04    1.887440e+07      2093.320068  ...  0.000000              True
# 2015-08-05    1.770940e+07      2099.840088  ... -0.155492              True
# 2015-08-06    1.614133e+07      2083.560059  ...  1.208832              True
# 2015-08-07    1.515290e+07      2077.570068  ... -0.102857             False
# 2015-08-10    1.509752e+07      2104.179932  ...  0.877036              True
#
#             Price History 2W  Price History 3W  Price History 001M  \
# Date
# 2015-08-04              True              True                True
# 2015-08-05              True              True                True
# 2015-08-06              True              True                True
# 2015-08-07             False             False               False
# 2015-08-10              True              True                True
#
#             Price History 003M  Price History 006M  Price History 012M  \
# Date
# 2015-08-04                True                True                True
# 2015-08-05                True                True                True
# 2015-08-06                True                True                True
# 2015-08-07               False               False               False
# 2015-08-10                True                True                True
#
#             Price History 036M  Price History 060M
# Date
# 2015-08-04                True                True
# 2015-08-05                True                True
# 2015-08-06                True                True
# 2015-08-07               False               False
# 2015-08-10                True                True
#
# [5 rows x 21 columns]

# %%
start_date, end_date = df.index.min(), df.index.max()

# %%
key_ticker_price = '{} Adj Close'.format(ticker)

# %%
print(df_filtered[df_filtered['Price History 003M']].tail())
# Out:
#             XOM Adj Close    SMA 10W  Trend SMA 10W  Stage Trend 10W  \
# Date
# 2019-03-21      76.321495  69.452304         0.0010              NaN
# 2019-04-04      76.564125  70.545471         0.0028              NaN
# 2019-04-05      76.974686  70.781412         0.0033              NaN
# 2019-04-08      77.450592  70.982886         0.0028              NaN
# 2019-04-23      77.805191  72.608906         0.0022              NaN
#
#               SMA 30W  Trend SMA 30W  Stage Trend 30W  XOM Volume  \
# Date
# 2019-03-21  72.504603         0.0002              NaN  10117000.0
# 2019-04-04  72.616978         0.0002              NaN   9360600.0
# 2019-04-05  72.636099         0.0003              NaN  10059100.0
# 2019-04-08  72.651543         0.0002              NaN   9108200.0
# 2019-04-23  72.759513         0.0003              NaN  10595100.0
#
#             Volume SMA 30D  ^GSPC Adj Close  ...       RSM  Price History 1W  \
# Date                                         ...
# 2019-03-21    1.321882e+07      2854.879883  ...  0.701317              True
# 2019-04-04    1.218736e+07      2879.389893  ...  0.341927              True
# 2019-04-05    1.220535e+07      2892.739990  ...  0.434054              True
# 2019-04-08    1.219981e+07      2895.770020  ...  0.967909              True
# 2019-04-23    1.058859e+07      2933.679932  ...  0.346234              True
#
#             Price History 2W  Price History 3W  Price History 001M  \
# Date
# 2019-03-21              True              True                True
# 2019-04-04              True              True                True
# 2019-04-05              True              True                True
# 2019-04-08              True              True                True
# 2019-04-23              True              True                True
#
#             Price History 003M  Price History 006M  Price History 012M  \
# Date
# 2019-03-21                True               False               False
# 2019-04-04                True               False               False
# 2019-04-05                True               False               False
# 2019-04-08                True               False               False
# 2019-04-23                True               False               False
#
#             Price History 036M  Price History 060M
# Date
# 2019-03-21               False               False
# 2019-04-04               False               False
# 2019-04-05               False               False
# 2019-04-08               False               False
# 2019-04-23               False               False
#
# [5 rows x 21 columns]

# %% [markdown]
# ### Visualise The Data

# %%
# %matplotlib widget
fig, (ax1, ax2, ax3) = plt.subplots(3, sharex = True)
fig.set_size_inches(15, 12)
fig.suptitle('{0} - Technical Analysis [from {1} to {2}]'.format(ticker, dt.datetime.strftime(start_date, '%d-%b-%Y'), dt.datetime.strftime(end_date, '%d-%b-%Y')))
num_rows = 9
num_cols = 1
num_rows_ax1 = 5
num_rows_ax2 = 2
num_rows_ax3 = 2
ax1 = plt.subplot2grid((num_rows, num_cols), (0, 0), rowspan=num_rows_ax1, colspan=1)
ax2 = plt.subplot2grid((num_rows, num_cols), (5, 0), rowspan=num_rows_ax2, colspan=1, sharex=ax1)
ax3 = plt.subplot2grid((num_rows, num_cols), (7, 0), rowspan=num_rows_ax3, colspan=1, sharex=ax1)

# Main share price chart
ax1.plot(df_filtered['{} Adj Close'.format(ticker)], label='{} Adj Close'.format(ticker))
ax1.plot(df_filtered['SMA 10W'], label='SMA - 10 week')
ax1.plot(df_filtered['SMA 30W'], label='SMA - 30 week')

ax1.plot(df_filtered[df_filtered['Price History 001M']]['{} Adj Close'.format(ticker)], 'c^', label='Local Maxima 1 M')
ax1.plot(df_filtered[df_filtered['Price History 036M']]['{} Adj Close'.format(ticker)], 'b^', label='Local Maxima 36 M')

ax1.plot(df_filtered[df_filtered['Stage Trend 30W'] == 1]['SMA 30W'], 'g^')
ax1.plot(df_filtered[df_filtered['Stage Trend 30W'] == -1]['SMA 30W'], 'rv')
ax1.plot(df_filtered[df_filtered['Stage Trend 30W'] == 0]['SMA 30W'], 'ys')

ax1.set_title = '{} Adj Close Price History'.format(ticker)
ax1.set_ylabel('Adj. Close Price in USD ($)')
ax1.legend(loc='upper left')

# Volume chart
ax2.bar(df_filtered.index.map(mdates.date2num), df_filtered['{} Volume'.format(ticker)])
ax2.plot(df_filtered['Volume SMA 30D'], label='SMA - 30 day', color='b', alpha=0.3)

ax2.legend(loc='upper left')
ax2.set_ylabel('Volumes (10 mio)')

# Mansfield Relative Strength chart
ax3.plot(df_filtered['RSM'], label='Mansfield RS')
ax3.axhline(y=0, color='g', alpha=0.4)

ax3.legend(loc='upper left')
ax3.set_ylabel('Mansfield RS')

plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
df_filtered[df_filtered['Stage Trend 30W'] == 1]
# Out:
#             XOM Adj Close    SMA 10W  Trend SMA 10W  Stage Trend 10W  \
# Date
# 2015-08-06      63.240810  62.744104         0.0040              1.0
# 2015-08-10      63.775311  62.845606         0.0037              1.0
# 2015-10-02      62.026012  60.749758         0.0005              1.0
# 2015-12-15      65.493889  64.378226         0.0014              NaN
# 2015-12-22      64.026176  64.722638         0.0011              NaN
# 2016-01-05      64.413727  65.295813         0.0011              NaN
# 2016-01-14      65.238266  65.491856         0.0005              NaN
# 2016-01-29      64.191086  65.086687        -0.0004              NaN
# 2016-02-03      64.710556  64.939895        -0.0007              NaN
# 2017-11-29      72.905106  71.273752         0.0012              NaN
# 2018-04-26      72.388336  69.903237        -0.0010              NaN
# 2018-05-09      71.555779  68.796698        -0.0013              NaN
# 2018-05-30      73.700821  69.278617         0.0011              NaN
# 2018-08-07      73.492836  73.335116         0.0008              1.0
# 2018-09-05      74.333099  73.528048         0.0006              NaN
# 2018-09-07      74.762505  73.580290         0.0002              NaN
# 2018-10-17      74.461014  74.790947        -0.0002              NaN
# 2018-12-04      73.305450  74.603201         0.0001              NaN
# 2019-01-18      67.362015  70.375926        -0.0023              NaN
# 2019-01-29      65.996117  69.558610        -0.0017              NaN
# 2019-01-31      67.629639  69.345808        -0.0015              NaN
# 2019-02-12      70.358734  69.033686        -0.0003              NaN
# 2019-03-26      75.546989  69.647425         0.0011              NaN
# 2019-04-11      76.470802  71.548026         0.0027              NaN
# 2019-06-18      71.486122  73.284112        -0.0004              NaN
# 2019-06-20      72.307259  73.202682        -0.0005              NaN
# 2019-10-22      66.020424  67.379029        -0.0014              NaN
# 2019-11-01      66.507759  66.771325        -0.0009              NaN
# 2019-11-21      67.377541  66.656881         0.0006              1.0
#
#               SMA 30W  Trend SMA 30W  Stage Trend 30W  XOM Volume  \
# Date
# 2015-08-06  62.744104         0.0040              1.0  13005200.0
# 2015-08-10  62.845606         0.0037              1.0  14876000.0
# 2015-10-02  60.749758         0.0005              1.0  18811300.0
# 2015-12-15  63.628380         0.0003              1.0  24366800.0
# 2015-12-22  63.657216         0.0001              1.0  13855800.0
# 2016-01-05  63.745372         0.0001              1.0  11993500.0
# 2016-01-14  63.679436         0.0002              1.0  33806700.0
# 2016-01-29  63.588638         0.0001              1.0  25161900.0
# 2016-02-03  63.575665         0.0001              1.0  25873700.0
# 2017-11-29  70.750260         0.0001              1.0   9725000.0
# 2018-04-26  71.024026         0.0001              1.0  14554400.0
# 2018-05-09  70.989018         0.0001              1.0  17142100.0
# 2018-05-30  71.209513         0.0003              1.0  16627500.0
# 2018-08-07  72.261717         0.0001              1.0  10698100.0
# 2018-09-05  72.237904         0.0001              1.0  13878400.0
# 2018-09-07  72.246007         0.0001              1.0  16417800.0
# 2018-10-17  72.781910         0.0001              1.0  12247700.0
# 2018-12-04  72.255641         0.0002              1.0  18540700.0
# 2019-01-18  72.071653         0.0001              1.0  15759200.0
# 2019-01-29  72.073265         0.0001              1.0  10513200.0
# 2019-01-31  72.082807         0.0001              1.0  19876700.0
# 2019-02-12  72.140231         0.0001              1.0  12599200.0
# 2019-03-26  72.517462         0.0001              1.0   9472800.0
# 2019-04-11  72.667417         0.0001              1.0   9115100.0
# 2019-06-18  72.309613         0.0001              1.0  10091500.0
# 2019-06-20  72.312626         0.0001              1.0  16229700.0
# 2019-10-22  70.079310         0.0002              1.0   9536000.0
# 2019-11-01  70.183274         0.0002              1.0  14108700.0
# 2019-11-21  70.262633         0.0001              1.0  14080500.0
#
#             Volume SMA 30D  ^GSPC Adj Close  ...        RSM  Price History 1W  \
# Date                                         ...
# 2015-08-06    1.614133e+07      2083.560059  ...   1.208832              True
# 2015-08-10    1.509752e+07      2104.179932  ...   0.877036              True
# 2015-10-02    1.796192e+07      1951.359985  ...   3.948507              True
# 2015-12-15    1.530246e+07      2043.410034  ...   2.051365              True
# 2015-12-22    1.593759e+07      2038.969971  ...  -0.038297             False
# 2016-01-05    1.557990e+07      2016.709961  ...   1.623236             False
# 2016-01-14    1.825821e+07      1921.839966  ...   7.794528              True
# 2016-01-29    1.899637e+07      1940.239990  ...   4.625750              True
# 2016-02-03    1.901635e+07      1912.530029  ...   6.901436              True
# 2017-11-29    8.840833e+06      2626.070068  ... -10.968880              True
# 2018-04-26    1.483879e+07      2666.939941  ...  -6.069695              True
# 2018-05-09    1.402542e+07      2697.790039  ...  -7.620792              True
# 2018-05-30    1.348630e+07      2724.010010  ...  -4.881475             False
# 2018-08-07    1.000478e+07      2858.449951  ...  -7.275657             False
# 2018-09-05    1.005867e+07      2888.600098  ...  -6.363267              True
# 2018-09-07    1.029216e+07      2871.679932  ...  -5.189333              True
# 2018-10-17    1.196858e+07      2809.209961  ...  -2.624229             False
# 2018-12-04    1.457193e+07      2700.060059  ...   0.622288             False
# 2019-01-18    1.692777e+07      2670.709961  ...  -5.773420              True
# 2019-01-29    1.596918e+07      2640.000000  ...  -6.435406             False
# 2019-01-31    1.607811e+07      2704.100098  ...  -6.340293              True
# 2019-02-12    1.321840e+07      2744.729980  ...  -3.849703              True
# 2019-03-26    1.310141e+07      2818.459961  ...   1.016965             False
# 2019-04-11    1.186695e+07      2888.320068  ...   0.012784             False
# 2019-06-18    1.036960e+07      2917.750000  ...  -6.179457              True
# 2019-06-20    1.040745e+07      2954.179932  ...  -6.199399              True
# 2019-10-22    1.032725e+07      2995.989990  ... -13.310317             False
# 2019-11-01    1.023225e+07      3066.909912  ... -14.280874              True
# 2019-11-21    1.165881e+07      3103.540039  ... -13.529032              True
#
#             Price History 2W  Price History 3W  Price History 001M  \
# Date
# 2015-08-06              True              True                True
# 2015-08-10              True              True                True
# 2015-10-02              True              True                True
# 2015-12-15             False             False               False
# 2015-12-22             False             False               False
# 2016-01-05             False             False               False
# 2016-01-14             False             False               False
# 2016-01-29             False             False               False
# 2016-02-03             False             False               False
# 2017-11-29             False             False               False
# 2018-04-26              True              True                True
# 2018-05-09             False             False               False
# 2018-05-30             False             False               False
# 2018-08-07             False             False               False
# 2018-09-05              True              True               False
# 2018-09-07              True              True                True
# 2018-10-17             False             False               False
# 2018-12-04             False             False               False
# 2019-01-18              True              True               False
# 2019-01-29             False             False               False
# 2019-01-31              True              True                True
# 2019-02-12              True              True                True
# 2019-03-26             False             False               False
# 2019-04-11             False             False               False
# 2019-06-18              True             False               False
# 2019-06-20              True              True                True
# 2019-10-22             False             False               False
# 2019-11-01             False             False               False
# 2019-11-21             False             False               False
#
#             Price History 003M  Price History 006M  Price History 012M  \
# Date
# 2015-08-06                True                True                True
# 2015-08-10                True                True                True
# 2015-10-02               False               False               False
# 2015-12-15               False               False               False
# 2015-12-22               False               False               False
# 2016-01-05               False               False               False
# 2016-01-14               False               False               False
# 2016-01-29               False               False               False
# 2016-02-03               False               False               False
# 2017-11-29               False               False               False
# 2018-04-26               False               False               False
# 2018-05-09               False               False               False
# 2018-05-30               False               False               False
# 2018-08-07               False               False               False
# 2018-09-05               False               False               False
# 2018-09-07               False               False               False
# 2018-10-17               False               False               False
# 2018-12-04               False               False               False
# 2019-01-18               False               False               False
# 2019-01-29               False               False               False
# 2019-01-31               False               False               False
# 2019-02-12               False               False               False
# 2019-03-26               False               False               False
# 2019-04-11               False               False               False
# 2019-06-18               False               False               False
# 2019-06-20               False               False               False
# 2019-10-22               False               False               False
# 2019-11-01               False               False               False
# 2019-11-21               False               False               False
#
#             Price History 036M  Price History 060M
# Date
# 2015-08-06                True                True
# 2015-08-10                True                True
# 2015-10-02               False               False
# 2015-12-15               False               False
# 2015-12-22               False               False
# 2016-01-05               False               False
# 2016-01-14               False               False
# 2016-01-29               False               False
# 2016-02-03               False               False
# 2017-11-29               False               False
# 2018-04-26               False               False
# 2018-05-09               False               False
# 2018-05-30               False               False
# 2018-08-07               False               False
# 2018-09-05               False               False
# 2018-09-07               False               False
# 2018-10-17               False               False
# 2018-12-04               False               False
# 2019-01-18               False               False
# 2019-01-29               False               False
# 2019-01-31               False               False
# 2019-02-12               False               False
# 2019-03-26               False               False
# 2019-04-11               False               False
# 2019-06-18               False               False
# 2019-06-20               False               False
# 2019-10-22               False               False
# 2019-11-01               False               False
# 2019-11-21               False               False
#
# [29 rows x 21 columns]

# %%
df_sandp = dc.get_ticker_data_from_yahoo(ticker)
# Out:
# [{data_collection.py:45} INFO - end_date: 2020-08-02 00:00:00 and max_index: 2020-07-31 00:00:00
# [{data_collection.py:46} INFO - start_date: 2015-08-04 00:00:00 and min_index: 2015-08-04 00:00:00
# [{data_collection.py:49} WARNING - Returning an empty dataframe
# [{data_collection.py:95} INFO - Dumping data for XOM

# %%
df_sandp[-1000:].Close
# Out:
# Date
# 2016-08-11    86.720001
# 2016-08-12    87.849998
# 2016-08-15    87.809998
# 2016-08-16    87.919998
# 2016-08-17    88.110001
#                 ...
# 2020-07-27    44.070000
# 2020-07-28    43.549999
# 2020-07-29    44.029999
# 2020-07-30    41.869999
# 2020-07-31    42.080002
# Name: Close, Length: 1000, dtype: float64

# %% [markdown]
# ### trendln
#
# Check out the support and resistance file at trendln: https://github.com/GregoryMorse/trendln

# %%
df['SMA 30W']
# Out:
# Date
# 2015-08-04    62.495750
# 2015-08-05    62.495750
# 2015-08-06    62.744104
# 2015-08-07    62.613180
# 2015-08-10    62.845606
#                 ...
# 2020-07-27    54.199853
# 2020-07-28    54.084297
# 2020-07-29    53.968705
# 2020-07-30    53.846787
# 2020-07-31    53.733422
# Name: SMA 30W, Length: 1258, dtype: float64

# %%
df['SMA 30W'].rolling(window=2).aggregate(lambda x: (x[1] - x[0]) / x[0])
# Out:
# Date
# 2015-08-04         NaN
# 2015-08-05    0.000000
# 2015-08-06    0.003974
# 2015-08-07   -0.002087
# 2015-08-10    0.003712
#                 ...
# 2020-07-27   -0.002114
# 2020-07-28   -0.002132
# 2020-07-29   -0.002137
# 2020-07-30   -0.002259
# 2020-07-31   -0.002105
# Name: SMA 30W, Length: 1258, dtype: float64

# %%
df[df['Trend SMA 30W'].rolling(window=2).aggregate(lambda x: ((x[0] < 0 and x[1] > 0) or (x[0] > 0 and x[1] < 0))).astype(bool)].index
# Out:
# DatetimeIndex(['2015-08-04', '2015-08-07', '2015-08-10', '2015-08-19',
#                '2015-10-02', '2015-12-07', '2015-12-15', '2016-01-14',
#                '2016-02-01', '2016-02-03', '2018-04-27', '2019-01-22'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df['Trend SMA 30W Rounded'] = round(df['Trend SMA 30W'], 4)

# %%
df[df['Trend SMA 30W Rounded'].rolling(window=2).aggregate(lambda x: ((x[0] < 0 and x[1] > 0) or (x[0] > 0 and x[1] < 0))).astype(bool)].index
# Out:
# DatetimeIndex(['2015-08-04', '2015-08-07', '2015-08-10', '2015-08-19',
#                '2015-10-02', '2015-12-07', '2015-12-15', '2016-01-14',
#                '2016-02-01', '2016-02-03', '2018-04-27', '2019-01-22'],
#               dtype='datetime64[ns]', name='Date', freq=None)

# %%
df[df['Trend SMA 30W Rounded'].rolling(window=2).aggregate(lambda x: (x[0] == 0 or x[1] == 0)).astype(bool)].index
# Out:
# DatetimeIndex(['2015-08-04', '2015-08-05', '2015-08-06', '2015-09-30',
#                '2015-10-01', '2015-12-18', '2015-12-21', '2015-12-22',
#                '2016-01-04', '2016-01-05',
#                ...
#                '2019-11-01', '2019-11-13', '2019-11-14', '2019-11-15',
#                '2019-11-18', '2019-11-20', '2019-11-21', '2019-11-26',
#                '2019-11-27', '2019-11-29'],
#               dtype='datetime64[ns]', name='Date', length=133, freq=None)

# %%
len(df[df['Trend SMA 30W Rounded'] == 0].index.tolist())
# Out:
# 87

# %%
print(df[df.index > pd.to_datetime('2018-03-01')][:10])
# Out:
#             XOM Adj Close    SMA 10W  Trend SMA 10W  Stage Trend 10W  \
# Date
# 2018-03-02      67.634674  73.310517        -0.0007              NaN
# 2018-03-05      68.279236  73.266207        -0.0006              NaN
# 2018-03-06      68.198662  73.216696        -0.0007              NaN
# 2018-03-07      66.479813  73.139718        -0.0011              NaN
# 2018-03-08      66.354492  73.056898        -0.0011              NaN
# 2018-03-09      66.748390  72.983630        -0.0010              NaN
# 2018-03-12      67.357132  72.911969        -0.0010              NaN
# 2018-03-13      66.721535  72.823633        -0.0012              NaN
# 2018-03-14      65.888962  72.710489        -0.0016              NaN
# 2018-03-15      66.623055  72.605681        -0.0014              NaN
#
#               SMA 30W  Trend SMA 30W  Stage Trend 30W  XOM Volume  \
# Date
# 2018-03-02  71.595601        -0.0002              NaN  15630300.0
# 2018-03-05  71.581481        -0.0002              NaN  14891000.0
# 2018-03-06  71.571327        -0.0001              NaN  10754300.0
# 2018-03-07  71.551428        -0.0003              NaN  27255500.0
# 2018-03-08  71.527364        -0.0003              NaN  19299800.0
# 2018-03-09  71.507555        -0.0003              NaN  19714100.0
# 2018-03-12  71.489113        -0.0003              NaN  14226700.0
# 2018-03-13  71.464745        -0.0003              NaN  13739700.0
# 2018-03-14  71.436661        -0.0004              NaN  14820700.0
# 2018-03-15  71.411037        -0.0004              NaN  15640600.0
#
#             Volume SMA 30D  ^GSPC Adj Close  ...  Price History 1W  \
# Date                                         ...
# 2018-03-02    1.675382e+07      2691.250000  ...             False
# 2018-03-05    1.681386e+07      2720.939941  ...             False
# 2018-03-06    1.682999e+07      2728.120117  ...             False
# 2018-03-07    1.739578e+07      2726.800049  ...             False
# 2018-03-08    1.769523e+07      2738.969971  ...             False
# 2018-03-09    1.797664e+07      2786.570068  ...             False
# 2018-03-12    1.810038e+07      2783.020020  ...             False
# 2018-03-13    1.824785e+07      2765.310059  ...             False
# 2018-03-14    1.832827e+07      2749.479980  ...             False
# 2018-03-15    1.836947e+07      2747.330078  ...             False
#
#             Price History 2W  Price History 3W  Price History 001M  \
# Date
# 2018-03-02             False             False               False
# 2018-03-05             False             False               False
# 2018-03-06             False             False               False
# 2018-03-07             False             False               False
# 2018-03-08             False             False               False
# 2018-03-09             False             False               False
# 2018-03-12             False             False               False
# 2018-03-13             False             False               False
# 2018-03-14             False             False               False
# 2018-03-15             False             False               False
#
#             Price History 003M  Price History 006M  Price History 012M  \
# Date
# 2018-03-02               False               False               False
# 2018-03-05               False               False               False
# 2018-03-06               False               False               False
# 2018-03-07               False               False               False
# 2018-03-08               False               False               False
# 2018-03-09               False               False               False
# 2018-03-12               False               False               False
# 2018-03-13               False               False               False
# 2018-03-14               False               False               False
# 2018-03-15               False               False               False
#
#             Price History 036M  Price History 060M  Trend SMA 30W Rounded
# Date
# 2018-03-02               False               False                -0.0002
# 2018-03-05               False               False                -0.0002
# 2018-03-06               False               False                -0.0001
# 2018-03-07               False               False                -0.0003
# 2018-03-08               False               False                -0.0003
# 2018-03-09               False               False                -0.0003
# 2018-03-12               False               False                -0.0003
# 2018-03-13               False               False                -0.0003
# 2018-03-14               False               False                -0.0004
# 2018-03-15               False               False                -0.0004
#
# [10 rows x 22 columns]

# %%
def mark_trend_turn(x):
    if (x[0] <= 0 and x[1] > 0):
        return 1
    elif (x[0] != 0 and x[1] == 0):
        return 0
    elif (x[0] >= 0 and x[1] < 0):
        return -1
    else:
        return np.NaN

# %%
df['Trend SMA 30W'].rolling(window=2).apply(mark_trend_turn).value_counts()
# Out:
#  0.0    45
#  1.0    29
# -1.0    28
# Name: Trend SMA 30W, dtype: int64
